# %%
# Test 1: Basic Python execution
print("✅ Jupyter Notebook is running!")

# Test 2: Check current working directory (should match your project folder)
import os
print("📁 Current folder:", os.getcwd())

# Test 3: Use some common packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create simple data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot it
plt.plot(x, y)
plt.title("📊 Test Plot: Sine Wave")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.show()
# Out:
# ✅ Jupyter Notebook is running!
# 📁 Current folder: /Users/sanjaywaradkar/Documents/ML-101-Projects/ML-101/Test-Day-1
# /Users/sanjaywaradkar/miniforge3/envs/myenv/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
